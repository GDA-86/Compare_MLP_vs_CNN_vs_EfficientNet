# %% [markdown]
# # Итоговый отчет

# %% [markdown]
# | Модель | Точность |
# | :--- | :--- |
# | MLP из дисциплины «Введение в глубокое обучение», модуль 3 «Основы работы с PyTorch», урок «Практика: MLP для классификации музыкальных жанров» | 32.45% |
# | Свёрточная сеть | 56.29% |
# | EfficientNet B0 | 60,93% |

# %% [markdown]
# | Архитектура | Входные данные | Базовый слой | Учёт геометрии | Параметры |
# | :--- | :--- | :--- | :--- | :--- |
# | **MLP (Полносвязная сеть)** | Плоский вектор (1D) | Линейный слой (Linear/Dense) | Игнорирует связи пикселей | Очень много (растёт с размером фото) |
# | **CNN (Свёрточная сеть)** | Тензор изображения (3D) | Свёрточный слой (Conv2D) | Сохраняет локальные связи | Умеренно (за счёт разделения весов) |
# | **EfficientNet B0** | Тензор изображения (3D) | Глубинная разделимая свёртка (MBConv) | Эффективно кодирует контекст | Оптимально (высокая точность / мало весов) |

# %% [markdown]
# | Архитектура | Преимущества (+) | Недостатки (-) |
# | :--- | :--- | :--- |
# | **MLP** | • Простая в реализации.<br>• Быстро обучается на малых данных.<br>• Хорошо находит линейные зависимости. | • Переводит 2D изображение в одномерный вектор .<br>• Веса растут со знаком умножения пикселей.<br>• Быстро переобучается на больших фото. |
# | **CNN** | • Сохраняет пространственные связи пикселей.<br>• Экономит веса за счет разделения фильтров.<br>• Устойчива к сдвигу объектов на фото. | • Требует ручного подбора слоев и ядер.<br>• Тяжело масштабируется под новое разрешение.<br>• Плохо улавливает глобальный контекст. |
# | **EfficientNet B0** | • Высокая точность при этом требует меньше параметров .<br>• Наличие предобученных весов <br>  | • Сложная архитектура для понимания.<br>• Высокие требования к памяти при обучении.<br>• Сложнее модифицировать вручную.  |
